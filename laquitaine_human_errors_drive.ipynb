# %% [markdown]
# ## Study Laquitaine & Gardner human motion direction estimation errors
#
# author: steeve.laquitaine@epfl.ch
#
# Inpired from [Laquitaine & Gardner, Neuron, 2018](https://doi.org/10.1016/j.neuron.2017.12.011)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, requests
from matplotlib import colors
from matplotlib import rcParams
from matplotlib.colors import ListedColormap
from numpy import pi
from copy import copy

# %%
# @title Figure settings
rcParams['figure.figsize'] = [20, 4]
rcParams['font.size'] = 11
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
rcParams['figure.autolayout'] = True

# %% [markdown]
# TODO: ADD VIDEO OF TASK AND FIGURE OF EXPERIMENT

# %%
# @title Data retrieval

url = "https://github.com/steevelaquitaine/projInference/raw/gh-pages/data/csv/data01_direction4priors.csv"
try:
  RequestAPI = requests.get(url)
except requests.ConnectionError:
  print("Failed to download data. Please contact steeve.laquitaine@epfl.ch")
else:
  if RequestAPI.status_code != requests.codes.ok:
    print("Failed to download data. Please contact steeve.laquitaine@epfl.ch")
  else:
    with open("data01_direction4priors.csv", "wb") as fid:
      fid.write(RequestAPI.content)

# %% [markdown]
# ### Data dictionary
#
# `data` contains sessions from 12 human subjects, data from [Laquitaine & Gardner, 2018](https://doi.org/10.1016/j.neuron.2017.12.011).
#
# Subjects had to estimate the direction of stimulus motion directions.
#
# * `data['trial_index']`: trial index
# * `data['trial_time']`: time at which trial starts with th e central fixation dot
# * `data['response_arrow_start_angle']`: the angle of the response arrow at the start of the response phase.
# * `data['motion_direction']`: the stimulus motion direction
# * `data['motion_coherence']`: the stimulus motion coherence
# * `data['estimate_x']`: x cartesian coordinate of the stimulus motion direction
# * `data['estimate_y']`: y cartesian coordinate of the stimulus motion direction
# * `data['reaction_time']`: subject's reaction time
# * `data['raw_response_time']`: subject response time since the start of the run (of about 200 trials)
# * `data['prior_std']`: It is the standard deviation of the statistical distribution (motion direction generative process over trials, which we call "experimental prior") from which we sampled the stimulus motion direction displayed in each trial.
# * `data['prior_mean']`: the most frequently displayed motion direction. It is the mean of the statistical distribution (motion direction generative process over trials, which we call "experimental prior") from which we sampled the stimulus motion direction displayed in each trial.
# * `data['subject_id']`: the id of the subject for which behavior was recorded.
# * `data['experiment_name']`: the name of the experiment. This dataaset only contains the "data01_direction4priors" experiment in which subject underwent a task in which four motion direction were sampled from one of four priors with 10, 40, 60 and 80 degree standard deviations in each block of about 200 trials. The mean of the "experimental prior"  was fixed at 225 deg.
# * `data['experiment_id']`: the id of the experiment.
# * `data['session_id']`: the id of the session.
# * `data['run_id']`: the id of the run.
#
#
# The complete original dataset is stored in .mat files here: https://data.mendeley.com/datasets/nxkvtrj9ps/1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib

# @title Data loading
data = pd.read_csv("data01_direction4priors.csv")

def cartesian_to_degrees(x, y):
    angle_rad = np.arctan2(y, x)
    angle_deg = np.degrees(angle_rad)
    return angle_deg

data['estimate_degree'] =cartesian_to_degrees(data['estimate_x'], data['estimate_y'])


def reform(x):
    if x < 0:
        x = x + 360
        return x
    else:
        return x

def dis_deg_ref(x):
    if x> 180:
        x = 360 - x
        return x
    if x< -180:
        x = 360 + x
    return x



# if data['estimate_degree'] < 0 :
#     data[ 'estimate_dagree'] = data['estimate_degree'] + 360
data['estimate_degree' ] = data['estimate_degree'].apply(reform)

data['estimate_error'] = data['motion_direction'] - data["estimate_degree"]

# data[ ['trial_index' , 'motion_direction' , 'estimate_degree' ,  'estimate_error' ]]
data[ ['trial_index' , 'motion_direction' , 'estimate_degree' ,  'prior_mean' ]]


# def binarize(i):
#     if i <



data['sensory_bias'] = data['estimate_degree'] - data['motion_direction']
data['prior_bias'] = data['estimate_degree'] - data['prior_mean']

data['sensory_bias'] = data['sensory_bias'].apply(dis_deg_ref)
data['prior_bias'] = data['prior_bias'].apply(dis_deg_ref)

data['distance'] = abs(data['motion_direction'] - data['prior_mean'])
# data['']

data['binarized_estimate_degree'] = np.where((abs(data['sensory_bias']) - abs(data['prior_bias'])) > 0, 1, 0)

# data[ data['sensory_bias'] > 180 ]
data.loc[-5:,['trial_index','prior_mean','estimate_degree','motion_direction','sensory_bias', 'prior_bias','reaction_time','prior_std','motion_coherence','distance','binarized_estimate_degree']]
# data[-5:]
# Out:
#        trial_index  prior_mean  estimate_degree  motion_direction  \
# 0                1         225       225.583113               225
# 1                2         225       223.291282               225
# 2                3         225       231.312691               235
# 3                4         225       230.166776               225
# 4                5         225       229.020860               215
# ...            ...         ...              ...               ...
# 83208          198         225       249.013514               205
# 83209          199         225       219.997721               265
# 83210          200         225       268.246734               245
# 83211          201         225       274.075461               185
# 83212          202         225       232.904188               185
#
#        sensory_bias  prior_bias  reaction_time  prior_std  motion_coherence  \
# 0          0.583113    0.583113            NaN         10              0.12
# 1         -1.708718   -1.708718            NaN         10              0.12
# 2         -3.687309    6.312691            NaN         10              0.06
# 3          5.166776    5.166776            NaN         10              0.06
# 4         14.020860    4.020860            NaN         10              0.24
# ...             ...         ...            ...        ...               ...
# 83208     44.013514   24.013514       1.298565         40              0.06
# 83209    -45.002279   -5.002279       1.175129         40              0.12
# 83210     23.246734   43.246734       0.793728         40              0.06
# 83211     89.075461   49.075461       1.363531         40              0.12
# 83212     47.904188    7.904188       1.553555         40              0.06
#
#        distance  binarized_estimate_degree
# 0             0                          0
# 1             0                          0
# 2            10                          0
# 3             0                          0
# 4            10                          1
# ...         ...                        ...
# 83208        20                          1
# 83209        40                          1
# 83210        20                          0
# 83211        40                          1
# 83212        40                          1
#
# [83213 rows x 11 columns]
# Warning: total number of rows (83213) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
data[-10:]
# data.value_counts()
# Out:
#        trial_index  trial_time  response_arrow_start_angle  motion_direction  \
# 83203          193  557.587047                        59.0               255
# 83204          194  560.578649                       336.0               235
# 83205          195  563.570631                       136.0               215
# 83206          196  566.332492                        79.0               245
# 83207          197  569.204476                       222.0               205
# 83208          198  571.895796                        47.0               205
# 83209          199  574.708207                       238.0               265
# 83210          200  577.408906                       300.0               245
# 83211          201  579.720922                        10.0               185
# 83212          202  582.602137                        33.0               185
#
#        motion_coherence  estimate_x  estimate_y  reaction_time  \
# 83203              0.06   -2.442998   -0.530810       1.463044
# 83204              0.24   -2.366307   -0.806594       1.473052
# 83205              0.12   -1.947298   -1.567811       1.257071
# 83206              0.12   -1.259037   -2.159821       1.358500
# 83207              0.06   -2.487798   -0.246696       1.174318
# 83208              0.06   -0.895369   -2.334162       1.298565
# 83209              0.12   -1.915175   -1.606893       1.175129
# 83210              0.06   -0.076489   -2.498830       0.793728
# 83211              0.12    0.177676   -2.493678       1.363531
# 83212              0.06   -1.507874   -1.994070       1.553555
#
#        raw_response_time  prior_std  ...          experiment_name  \
# 83203         560.349201         40  ...  data01_direction4priors
# 83204         563.340873         40  ...  data01_direction4priors
# 83205         566.116901         40  ...  data01_direction4priors
# 83206         568.989642         40  ...  data01_direction4priors
# 83207         571.677505         40  ...  data01_direction4priors
# 83208         574.493754         40  ...  data01_direction4priors
# 83209         577.181812         40  ...  data01_direction4priors
# 83210         579.492137         40  ...  data01_direction4priors
# 83211         582.373810         40  ...  data01_direction4priors
# 83212         585.445742         40  ...  data01_direction4priors
#
#        experiment_id session_id  run_id  estimate_degree  estimate_error  \
# 83203             12          6      30       192.258579       62.741421
# 83204             12          6      30       198.822500       36.177500
# 83205             12          6      30       218.838293       -3.838293
# 83206             12          6      30       239.760553        5.239447
# 83207             12          6      30       185.663072       19.336928
# 83208             12          6      30       249.013514      -44.013514
# 83209             12          6      30       219.997721       45.002279
# 83210             12          6      30       268.246734      -23.246734
# 83211             12          6      30       274.075461      -89.075461
# 83212             12          6      30       232.904188      -47.904188
#
#        sensory_bias  prior_bias  distance  binarized_estimate_degree
# 83203    -62.741421  -32.741421        30                          1
# 83204    -36.177500  -26.177500        10                          1
# 83205      3.838293   -6.161707        10                          0
# 83206     -5.239447   14.760553        20                          0
# 83207    -19.336928  -39.336928        20                          0
# 83208     44.013514   24.013514        20                          1
# 83209    -45.002279   -5.002279        40                          1
# 83210     23.246734   43.246734        20                          0
# 83211     89.075461   49.075461        40                          1
# 83212     47.904188    7.904188        40                          1
#
# [10 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['trial_index', 'trial_time', 'response_arrow_start_angle',
#        'motion_direction', 'motion_coherence', 'estimate_x', 'estimate_y',
#        'reaction_time', 'raw_response_time', 'prior_std', 'prior_mean',
#        'subject_id', 'experiment_name', 'experiment_id', 'session_id',
#        'run_id', 'estimate_degree', 'estimate_error', 'sensory_bias',
#        'prior_bias', 'distance', 'binarized_estimate_degree'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , classification_report, confusion_matrix

data = data.dropna(subset=['reaction_time'], axis= 0  ).reset_index(drop= True)
print( data.value_counts('subject_id') , '\n')

data_filtered = data[ (data['subject_id'] == 1) ]

num = data_filtered.value_counts('binarized_estimate_degree')
print('>>>>' ,num ,'\n')

min_num = np.min(np.array(num))
max_num_arg = np.argmax(np.array(num))
min_num_arg = np.argmin(np.array(num))

data_max = data_filtered[ data_filtered['binarized_estimate_degree'] == max_num_arg ]
data_max = data_max.sample( n=min_num )
data_min = data_filtered[ data_filtered['binarized_estimate_degree'] == min_num_arg ]

data_concat = pd.concat([data_max , data_min] , axis = 0 )

data_concat = data_concat.sample( frac=1 , random_state = 40).reset_index(drop = True)

num = data_concat.value_counts('binarized_estimate_degree')
print('>>>>' ,num ,'\n')
# data_concat.head()

x = data_concat[['reaction_time', 'prior_std' , 'motion_coherence' ,'distance']]
y = data_concat['binarized_estimate_degree']


scaler = StandardScaler()
x_normal = scaler.fit_transform(x)
print(x_normal)
# Out:
# subject_id
# 9     8632
# 6     7553
# 11    6474
# 12    6473
# 10    6043
# 3     3237
# 5     3237
# 7     3237
# 1     3236
# 8     3236
# dtype: int64
#
# >>>> binarized_estimate_degree
# 0    2277
# 1     959
# dtype: int64
#
# >>>> binarized_estimate_degree
# 0    959
# 1    959
# dtype: int64
#
# [[-0.65467406 -1.18994798  0.28619896 -0.61325242]
#  [ 1.50489174 -0.85072084  0.28619896 -0.61325242]
#  [ 1.21002805 -1.18994798 -0.7228628  -0.61325242]
#  ...
#  [-0.90492443 -1.18994798  2.30432247 -0.61325242]
#  [-1.21602514 -0.17226655  2.30432247  0.84156284]
#  [ 0.05812754  1.18464203 -0.7228628  -0.128314  ]]

# %%
x_train , x_test , y_train , y_test = train_test_split(x_normal, y, test_size = 0.2 ,shuffle = True )

reg_model = LogisticRegression() # ridge penalty='l2' , solver='lbfgs',
reg_model.fit( x_train , y_train)

print( '       [reaction_time', 'prior_std' , 'motion_coherence' ,'distance]')
print( 'Coef: ', reg_model.coef_)

y_train_pred = reg_model.predict(x_train)
print('\n>>>train:' , accuracy_score( y_train, y_train_pred))

y_test_pred = reg_model.predict(x_test)
print('>>>test:' , accuracy_score( y_test, y_test_pred) , '\n' )

print('\n',  classification_report(y_test , y_test_pred) )
print( confusion_matrix(y_test, y_test_pred, labels=[1,0])) #'1:sensory','0:prior'

# print(y_test_pred)
# print(y_test)
# Out:
#        [reaction_time prior_std motion_coherence distance]
# Coef:  [[ 0.05892034 -0.19810343 -0.63563224 -0.15510144]]
#
# >>>train: 0.6414602346805737
# >>>test: 0.6223958333333334
#
#
#                precision    recall  f1-score   support
#
#            0       0.71      0.51      0.60       208
#            1       0.57      0.75      0.65       176
#
#     accuracy                           0.62       384
#    macro avg       0.64      0.63      0.62       384
# weighted avg       0.64      0.62      0.62       384
#
# [[132  44]
#  [101 107]]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation, Dropout , Input
from tensorflow.keras.metrics import AUC , Recall
from tensorflow.keras import regularizers


# Convert data to numpy arrays
X_np = x_normal.astype('float32')
y_np = y.values.astype('int32')

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_np, y_np, test_size=0.2, random_state=42)

# Create a simple neural network model
# model = Sequential()
# model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
# model.add(Dense(64, activation='relu')
# model.add(Dense(1, activation='sigmoid'))
regularize_parameter = 0.01
model = Sequential ( [Input (shape =  x_train.shape[-1] )
                        ,Dense(16 , activation= 'relu' , kernel_regularizer = regularizers.l1(regularize_parameter) , name = 'L1' )
                        ,BatchNormalization()
                        ,Dense(64 , activation = 'relu' , kernel_regularizer = regularizers.l1(regularize_parameter) , name = 'L2')
                        ,BatchNormalization()
                        # ,Dense(128, activation= 'relu' , kernel_regularizer = regularizers.l1(regularize_parameter) , name = 'L3')
                        # ,Dropout(0.1)
                        # ,BatchNormalization()
                        ,Dense(16, activation= 'relu' , kernel_regularizer = regularizers.l1(regularize_parameter) , name = 'L4')
                        ,Dense(1 , activation= 'sigmoid' , name = 'L5')
                    ] )

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Training the model
Early = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', verbose=1 ,mode='max',patience=10)
num_epochs = 150
history = model.fit(X_train, y_train, batch_size=64, epochs=num_epochs, validation_split=0.1, verbose=1)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy*100:.2f}%")

# Plot learning curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), history.history['loss'], label='Train Loss')
plt.plot(range(1, num_epochs+1), history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), history.history['accuracy'], label='Train Accuracy')
plt.plot(range(1, num_epochs+1), history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/150
# 22/22 [==============================] - 1s 17ms/step - loss: 10.8302 - accuracy: 0.6138 - val_loss: 9.9705 - val_accuracy: 0.6299
# Epoch 2/150
# 22/22 [==============================] - 0s 7ms/step - loss: 9.1522 - accuracy: 0.6848 - val_loss: 8.4092 - val_accuracy: 0.5584
# Epoch 3/150
# 22/22 [==============================] - 0s 7ms/step - loss: 7.6346 - accuracy: 0.7087 - val_loss: 7.0011 - val_accuracy: 0.5455
# Epoch 4/150
# 22/22 [==============================] - 0s 7ms/step - loss: 6.2825 - accuracy: 0.7123 - val_loss: 5.7528 - val_accuracy: 0.5130
# Epoch 5/150
# 22/22 [==============================] - 0s 7ms/step - loss: 5.1006 - accuracy: 0.7210 - val_loss: 4.6724 - val_accuracy: 0.5130
# Epoch 6/150
# 22/22 [==============================] - 0s 7ms/step - loss: 4.1011 - accuracy: 0.7203 - val_loss: 3.7733 - val_accuracy: 0.5000
# Epoch 7/150
# 22/22 [==============================] - 0s 8ms/step - loss: 3.2733 - accuracy: 0.7333 - val_loss: 3.0524 - val_accuracy: 0.5000
# Epoch 8/150
# 22/22 [==============================] - 0s 8ms/step - loss: 2.6361 - accuracy: 0.7159 - val_loss: 2.5162 - val_accuracy: 0.5000
# Epoch 9/150
# 22/22 [==============================] - 0s 7ms/step - loss: 2.1619 - accuracy: 0.7225 - val_loss: 2.1071 - val_accuracy: 0.5000
# Epoch 10/150
# 22/22 [==============================] - 0s 7ms/step - loss: 1.8097 - accuracy: 0.7254 - val_loss: 1.8207 - val_accuracy: 0.5000
# Epoch 11/150
# 22/22 [==============================] - 0s 7ms/step - loss: 1.5885 - accuracy: 0.7159 - val_loss: 1.6301 - val_accuracy: 0.5065
# Epoch 12/150
# 22/22 [==============================] - 0s 6ms/step - loss: 1.4067 - accuracy: 0.7290 - val_loss: 1.4780 - val_accuracy: 0.5000
# Epoch 13/150
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2804 - accuracy: 0.7239 - val_loss: 1.3673 - val_accuracy: 0.5000
# Epoch 14/150
# 22/22 [==============================] - 0s 8ms/step - loss: 1.1789 - accuracy: 0.7319 - val_loss: 1.2645 - val_accuracy: 0.5260
# Epoch 15/150
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0963 - accuracy: 0.7297 - val_loss: 1.1929 - val_accuracy: 0.5455
# Epoch 16/150
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0289 - accuracy: 0.7319 - val_loss: 1.1378 - val_accuracy: 0.5455
# Epoch 17/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.9900 - accuracy: 0.7232 - val_loss: 1.0906 - val_accuracy: 0.5584
# Epoch 18/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.9360 - accuracy: 0.7254 - val_loss: 1.0428 - val_accuracy: 0.5844
# Epoch 19/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.8877 - accuracy: 0.7341 - val_loss: 0.9969 - val_accuracy: 0.5779
# Epoch 20/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8502 - accuracy: 0.7246 - val_loss: 0.9502 - val_accuracy: 0.6494
# Epoch 21/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8257 - accuracy: 0.7297 - val_loss: 0.9213 - val_accuracy: 0.6753
# Epoch 22/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.8019 - accuracy: 0.7246 - val_loss: 0.8856 - val_accuracy: 0.6883
# Epoch 23/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7888 - accuracy: 0.7304 - val_loss: 0.8513 - val_accuracy: 0.7078
# Epoch 24/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7665 - accuracy: 0.7254 - val_loss: 0.8249 - val_accuracy: 0.7208
# Epoch 25/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7438 - accuracy: 0.7370 - val_loss: 0.7950 - val_accuracy: 0.7143
# Epoch 26/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7275 - accuracy: 0.7413 - val_loss: 0.7753 - val_accuracy: 0.7273
# Epoch 27/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7160 - accuracy: 0.7370 - val_loss: 0.7624 - val_accuracy: 0.7078
# Epoch 28/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.7052 - accuracy: 0.7341 - val_loss: 0.7494 - val_accuracy: 0.7143
# Epoch 29/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7005 - accuracy: 0.7355 - val_loss: 0.7366 - val_accuracy: 0.7013
# Epoch 30/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6876 - accuracy: 0.7478 - val_loss: 0.7389 - val_accuracy: 0.7208
# Epoch 31/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6874 - accuracy: 0.7304 - val_loss: 0.7304 - val_accuracy: 0.7273
# Epoch 32/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6859 - accuracy: 0.7304 - val_loss: 0.6968 - val_accuracy: 0.7143
# Epoch 33/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6799 - accuracy: 0.7326 - val_loss: 0.6995 - val_accuracy: 0.7208
# Epoch 34/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6655 - accuracy: 0.7420 - val_loss: 0.6940 - val_accuracy: 0.7208
# Epoch 35/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6667 - accuracy: 0.7355 - val_loss: 0.6883 - val_accuracy: 0.7208
# Epoch 36/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6547 - accuracy: 0.7399 - val_loss: 0.6889 - val_accuracy: 0.7273
# Epoch 37/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6584 - accuracy: 0.7326 - val_loss: 0.6759 - val_accuracy: 0.7338
# Epoch 38/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6576 - accuracy: 0.7341 - val_loss: 0.6734 - val_accuracy: 0.7273
# Epoch 39/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6496 - accuracy: 0.7428 - val_loss: 0.6734 - val_accuracy: 0.7208
# Epoch 40/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6368 - accuracy: 0.7413 - val_loss: 0.6773 - val_accuracy: 0.7273
# Epoch 41/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6392 - accuracy: 0.7420 - val_loss: 0.6822 - val_accuracy: 0.7208
# Epoch 42/150
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6382 - accuracy: 0.7399 - val_loss: 0.6700 - val_accuracy: 0.7273
# Epoch 43/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6343 - accuracy: 0.7362 - val_loss: 0.6591 - val_accuracy: 0.7273
# Epoch 44/150
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6284 - accuracy: 0.7348 - val_loss: 0.6431 - val_accuracy: 0.7273
# Epoch 45/150
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6237 - accuracy: 0.7435 - val_loss: 0.6384 - val_accuracy: 0.7273
# Epoch 46/150
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6251 - accuracy: 0.7384 - val_loss: 0.6526 - val_accuracy: 0.7273
# Epoch 47/150
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6280 - accuracy: 0.7362 - val_loss: 0.6389 - val_accuracy: 0.7273
# Epoch 48/150
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6236 - accuracy: 0.7326 - val_loss: 0.6446 - val_accuracy: 0.7273
# Epoch 49/150
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6284 - accuracy: 0.7326 - val_loss: 0.6598 - val_accuracy: 0.7208
# Epoch 50/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.6161 - accuracy: 0.7435 - val_loss: 0.6600 - val_accuracy: 0.7143
# Epoch 51/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6170 - accuracy: 0.7391 - val_loss: 0.6633 - val_accuracy: 0.7208
# Epoch 52/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6182 - accuracy: 0.7362 - val_loss: 0.7134 - val_accuracy: 0.6623
# Epoch 53/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.6121 - accuracy: 0.7413 - val_loss: 0.6446 - val_accuracy: 0.7013
# Epoch 54/150
# 22/22 [==============================] - 0s 12ms/step - loss: 0.6076 - accuracy: 0.7464 - val_loss: 0.6353 - val_accuracy: 0.7143
# Epoch 55/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6088 - accuracy: 0.7384 - val_loss: 0.6334 - val_accuracy: 0.7208
# Epoch 56/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6122 - accuracy: 0.7355 - val_loss: 0.6357 - val_accuracy: 0.7273
# Epoch 57/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.6018 - accuracy: 0.7486 - val_loss: 0.6212 - val_accuracy: 0.7208
# Epoch 58/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5985 - accuracy: 0.7435 - val_loss: 0.6212 - val_accuracy: 0.7208
# Epoch 59/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6044 - accuracy: 0.7348 - val_loss: 0.6264 - val_accuracy: 0.7273
# Epoch 60/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6073 - accuracy: 0.7384 - val_loss: 0.6399 - val_accuracy: 0.7143
# Epoch 61/150
# 22/22 [==============================] - 0s 13ms/step - loss: 0.6041 - accuracy: 0.7406 - val_loss: 0.6238 - val_accuracy: 0.7208
# Epoch 62/150
# 22/22 [==============================] - 0s 17ms/step - loss: 0.6007 - accuracy: 0.7348 - val_loss: 0.6182 - val_accuracy: 0.7208
# Epoch 63/150
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5958 - accuracy: 0.7420 - val_loss: 0.6214 - val_accuracy: 0.7143
# Epoch 64/150
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5965 - accuracy: 0.7391 - val_loss: 0.6221 - val_accuracy: 0.7273
# Epoch 65/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5944 - accuracy: 0.7428 - val_loss: 0.6127 - val_accuracy: 0.7273
# Epoch 66/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5858 - accuracy: 0.7478 - val_loss: 0.6221 - val_accuracy: 0.7208
# Epoch 67/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5848 - accuracy: 0.7493 - val_loss: 0.6183 - val_accuracy: 0.7143
# Epoch 68/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5996 - accuracy: 0.7355 - val_loss: 0.6115 - val_accuracy: 0.7143
# Epoch 69/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5883 - accuracy: 0.7377 - val_loss: 0.6118 - val_accuracy: 0.7208
# Epoch 70/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5846 - accuracy: 0.7464 - val_loss: 0.6170 - val_accuracy: 0.7078
# Epoch 71/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5939 - accuracy: 0.7377 - val_loss: 0.6271 - val_accuracy: 0.7273
# Epoch 72/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5878 - accuracy: 0.7362 - val_loss: 0.6104 - val_accuracy: 0.7338
# Epoch 73/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5862 - accuracy: 0.7391 - val_loss: 0.6084 - val_accuracy: 0.7143
# Epoch 74/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5852 - accuracy: 0.7457 - val_loss: 0.6028 - val_accuracy: 0.7273
# Epoch 75/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5778 - accuracy: 0.7362 - val_loss: 0.6072 - val_accuracy: 0.7013
# Epoch 76/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5884 - accuracy: 0.7406 - val_loss: 0.6089 - val_accuracy: 0.7013
# Epoch 77/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5827 - accuracy: 0.7442 - val_loss: 0.6026 - val_accuracy: 0.7143
# Epoch 78/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5861 - accuracy: 0.7333 - val_loss: 0.5988 - val_accuracy: 0.7273
# Epoch 79/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5835 - accuracy: 0.7341 - val_loss: 0.6100 - val_accuracy: 0.7143
# Epoch 80/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5781 - accuracy: 0.7464 - val_loss: 0.5986 - val_accuracy: 0.7208
# Epoch 81/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5768 - accuracy: 0.7304 - val_loss: 0.5934 - val_accuracy: 0.7273
# Epoch 82/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5815 - accuracy: 0.7442 - val_loss: 0.5954 - val_accuracy: 0.7078
# Epoch 83/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5826 - accuracy: 0.7355 - val_loss: 0.5952 - val_accuracy: 0.7273
# Epoch 84/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5813 - accuracy: 0.7457 - val_loss: 0.5998 - val_accuracy: 0.7078
# Epoch 85/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5839 - accuracy: 0.7406 - val_loss: 0.5950 - val_accuracy: 0.7273
# Epoch 86/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5712 - accuracy: 0.7514 - val_loss: 0.5970 - val_accuracy: 0.7338
# Epoch 87/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5785 - accuracy: 0.7428 - val_loss: 0.5927 - val_accuracy: 0.7143
# Epoch 88/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5778 - accuracy: 0.7348 - val_loss: 0.5866 - val_accuracy: 0.7403
# Epoch 89/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5680 - accuracy: 0.7486 - val_loss: 0.5931 - val_accuracy: 0.7143
# Epoch 90/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5751 - accuracy: 0.7348 - val_loss: 0.6022 - val_accuracy: 0.7273
# Epoch 91/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5816 - accuracy: 0.7420 - val_loss: 0.5902 - val_accuracy: 0.7273
# Epoch 92/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5693 - accuracy: 0.7449 - val_loss: 0.5953 - val_accuracy: 0.7273
# Epoch 93/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5767 - accuracy: 0.7370 - val_loss: 0.6056 - val_accuracy: 0.7208
# Epoch 94/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5878 - accuracy: 0.7297 - val_loss: 0.5829 - val_accuracy: 0.7208
# Epoch 95/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5859 - accuracy: 0.7261 - val_loss: 0.5975 - val_accuracy: 0.7403
# Epoch 96/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5758 - accuracy: 0.7442 - val_loss: 0.5890 - val_accuracy: 0.7273
# Epoch 97/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5798 - accuracy: 0.7362 - val_loss: 0.5899 - val_accuracy: 0.7273
# Epoch 98/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5751 - accuracy: 0.7413 - val_loss: 0.5942 - val_accuracy: 0.7013
# Epoch 99/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5680 - accuracy: 0.7370 - val_loss: 0.5906 - val_accuracy: 0.7208
# Epoch 100/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5679 - accuracy: 0.7406 - val_loss: 0.5889 - val_accuracy: 0.7532
# Epoch 101/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5712 - accuracy: 0.7355 - val_loss: 0.5932 - val_accuracy: 0.7143
# Epoch 102/150
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5706 - accuracy: 0.7399 - val_loss: 0.5887 - val_accuracy: 0.7273
# Epoch 103/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5749 - accuracy: 0.7341 - val_loss: 0.5851 - val_accuracy: 0.7273
# Epoch 104/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.5701 - accuracy: 0.7435 - val_loss: 0.5821 - val_accuracy: 0.7208
# Epoch 105/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.5649 - accuracy: 0.7399 - val_loss: 0.5794 - val_accuracy: 0.7338
# Epoch 106/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5663 - accuracy: 0.7384 - val_loss: 0.5795 - val_accuracy: 0.7338
# Epoch 107/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5668 - accuracy: 0.7348 - val_loss: 0.5835 - val_accuracy: 0.7143
# Epoch 108/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5636 - accuracy: 0.7471 - val_loss: 0.5838 - val_accuracy: 0.7208
# Epoch 109/150
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5625 - accuracy: 0.7493 - val_loss: 0.5817 - val_accuracy: 0.7013
# Epoch 110/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5698 - accuracy: 0.7449 - val_loss: 0.5830 - val_accuracy: 0.7403
# Epoch 111/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5674 - accuracy: 0.7370 - val_loss: 0.5854 - val_accuracy: 0.7143
# Epoch 112/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5598 - accuracy: 0.7558 - val_loss: 0.5762 - val_accuracy: 0.7273
# Epoch 113/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5677 - accuracy: 0.7362 - val_loss: 0.5816 - val_accuracy: 0.7208
# Epoch 114/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5642 - accuracy: 0.7449 - val_loss: 0.5869 - val_accuracy: 0.7273
# Epoch 115/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5680 - accuracy: 0.7420 - val_loss: 0.5879 - val_accuracy: 0.7208
# Epoch 116/150
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5635 - accuracy: 0.7580 - val_loss: 0.5792 - val_accuracy: 0.7338
# Epoch 117/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.5591 - accuracy: 0.7420 - val_loss: 0.5820 - val_accuracy: 0.7208
# Epoch 118/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.5639 - accuracy: 0.7486 - val_loss: 0.5827 - val_accuracy: 0.7403
# Epoch 119/150
# 22/22 [==============================] - 0s 11ms/step - loss: 0.5685 - accuracy: 0.7333 - val_loss: 0.5806 - val_accuracy: 0.7013
# Epoch 120/150
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5680 - accuracy: 0.7413 - val_loss: 0.5903 - val_accuracy: 0.7143
# Epoch 121/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.7478 - val_loss: 0.5868 - val_accuracy: 0.7143
# Epoch 122/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5668 - accuracy: 0.7399 - val_loss: 0.5840 - val_accuracy: 0.7273
# Epoch 123/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5771 - accuracy: 0.7304 - val_loss: 0.5889 - val_accuracy: 0.7208
# Epoch 124/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5673 - accuracy: 0.7391 - val_loss: 0.6076 - val_accuracy: 0.7143
# Epoch 125/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5647 - accuracy: 0.7420 - val_loss: 0.5776 - val_accuracy: 0.7208
# Epoch 126/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5680 - accuracy: 0.7457 - val_loss: 0.5992 - val_accuracy: 0.7143
# Epoch 127/150
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5680 - accuracy: 0.7435 - val_loss: 0.5834 - val_accuracy: 0.7273
# Epoch 128/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5651 - accuracy: 0.7442 - val_loss: 0.5792 - val_accuracy: 0.7143
# Epoch 129/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5639 - accuracy: 0.7449 - val_loss: 0.5765 - val_accuracy: 0.7143
# Epoch 130/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5661 - accuracy: 0.7478 - val_loss: 0.5823 - val_accuracy: 0.7143
# Epoch 131/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5609 - accuracy: 0.7370 - val_loss: 0.5802 - val_accuracy: 0.7143
# Epoch 132/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5651 - accuracy: 0.7384 - val_loss: 0.5762 - val_accuracy: 0.7273
# Epoch 133/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5571 - accuracy: 0.7413 - val_loss: 0.5769 - val_accuracy: 0.7078
# Epoch 134/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5575 - accuracy: 0.7457 - val_loss: 0.5877 - val_accuracy: 0.7143
# Epoch 135/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5568 - accuracy: 0.7413 - val_loss: 0.5840 - val_accuracy: 0.7078
# Epoch 136/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5567 - accuracy: 0.7428 - val_loss: 0.5872 - val_accuracy: 0.7078
# Epoch 137/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5561 - accuracy: 0.7493 - val_loss: 0.5791 - val_accuracy: 0.7143
# Epoch 138/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5590 - accuracy: 0.7399 - val_loss: 0.5828 - val_accuracy: 0.7273
# Epoch 139/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5662 - accuracy: 0.7377 - val_loss: 0.6064 - val_accuracy: 0.7273
# Epoch 140/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5642 - accuracy: 0.7420 - val_loss: 0.5928 - val_accuracy: 0.7273
# Epoch 141/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5635 - accuracy: 0.7449 - val_loss: 0.5875 - val_accuracy: 0.7208
# Epoch 142/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5635 - accuracy: 0.7457 - val_loss: 0.5875 - val_accuracy: 0.7273
# Epoch 143/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5654 - accuracy: 0.7355 - val_loss: 0.5882 - val_accuracy: 0.7338
# Epoch 144/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5644 - accuracy: 0.7478 - val_loss: 0.5811 - val_accuracy: 0.7338
# Epoch 145/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5684 - accuracy: 0.7406 - val_loss: 0.5993 - val_accuracy: 0.7143
# Epoch 146/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5644 - accuracy: 0.7442 - val_loss: 0.5950 - val_accuracy: 0.7208
# Epoch 147/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5570 - accuracy: 0.7362 - val_loss: 0.5867 - val_accuracy: 0.7273
# Epoch 148/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5600 - accuracy: 0.7464 - val_loss: 0.5836 - val_accuracy: 0.7273
# Epoch 149/150
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5628 - accuracy: 0.7406 - val_loss: 0.5799 - val_accuracy: 0.7078
# Epoch 150/150
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5628 - accuracy: 0.7391 - val_loss: 0.5817 - val_accuracy: 0.7273
# Test Loss: 0.5301, Test Accuracy: 76.30%

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
import graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_graphviz

x_train , x_test , y_train , y_test = train_test_split(x_normal, y, test_size = 0.2 ,shuffle = True )

# print(x_train)

forest = RandomForestClassifier( n_estimators=200 , random_state = 1899)
forest.fit(x_train , y_train)
pred_forest = forest.predict(x_test)
print(confusion_matrix(y_test,pred_forest))
print(classification_report(y_test,pred_forest))

forest_out = export_graphviz( forest.estimators_[0] , feature_names= list(x.columns) , class_names= ['sensory','prior'] , filled = True , rounded=True )
forest_file = graphviz.Source(forest_out, format= 'png')
forest_file.render('Source.gv.png' , view=False, cleanup=True, quiet=True)
# Out:
# [[126  67]
#  [ 65 126]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.66       193
#            1       0.65      0.66      0.66       191
#
#     accuracy                           0.66       384
#    macro avg       0.66      0.66      0.66       384
# weighted avg       0.66      0.66      0.66       384
# 'Source.gv.png.png'

# %%
data[ (data['subject_id'] == 1) & (data['motion_direction'] == 225) ].value_counts('estimate_degree')
# Out:
# estimate_degree
# 225.192860    3
# 213.784419    2
# 218.792316    2
# 222.788368    2
# 230.862159    2
#              ..
# 216.368082    1
# 216.274549    1
# 216.188912    1
# 216.126965    1
# 341.870056    1
# Length: 490, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure( figsize = (16,4))
plt.scatter( data['estimate_error'] , data['trial_index'])
plt.xlabel('trial_index')
plt.ylabel('estimate_error')
# Out:
# Text(0, 0.5, 'estimate_error')

# %%
data_sub1 = data[ data['subject_id'] ==1 ]
plt.scatter( data_sub1['estimate_error'] , data_sub1['trial_index'] )

# %%
plt.hist( data['estimate_error'] , bins= 180 )
# Out:
# (array([  18.,   16.,   15.,   18.,   14.,   15.,   19.,   18.,   13.,
#           11.,   11.,   10.,    4.,    9.,    6.,   12.,    7.,    5.,
#            5.,    5.,    9.,    5.,    9.,    5.,    5.,    6.,    4.,
#            7.,   12.,    6.,   13.,   10.,   14.,   11.,   17.,   13.,
#           17.,   13.,   16.,   14.,   19.,   23.,   32.,   16.,   28.,
#           30.,   34.,   32.,   33.,   32.,   35.,   34.,   42.,   44.,
#           48.,   48.,   64.,   61.,   70.,   61.,   60.,   70.,   77.,
#          101.,   99.,  118.,  126.,  140.,  135.,  147.,  161.,  192.,
#          230.,  257.,  274.,  311.,  381.,  489.,  577.,  665.,  805.,
#          973., 1080., 1464., 1742., 1987., 2288., 2684., 2844., 2950.,
#         3069., 2968., 2639., 2244., 2040., 1597., 1357., 1122.,  903.,
#          820.,  653.,  550.,  491.,  436.,  381.,  305.,  267.,  246.,
#          237.,  197.,  211.,  159.,  172.,  151.,  133.,  122.,  114.,
#          102.,  112.,  107.,  102.,   97.,   99.,  107.,   99.,   75.,
#           94.,   80.,   82.,   69.,   91.,   66.,   79.,   82.,   67.,
#           78.,   58.,   66.,   71.,   58.,   52.,   42.,   49.,   46.,
#           50.,   29.,   30.,   28.,   42.,   41.,   31.,   30.,   18.,
#           28.,   26.,   22.,   28.,   21.,   20.,   28.,   17.,   25.,
#           24.,   17.,   28.,   23.,   35.,   38.,   26.,   25.,   28.,
#           31.,   21.,   26.,   33.,   22.,   32.,   29.,   18.,   24.]),
#  array([-3.54804161e+02, -3.50861678e+02, -3.46919194e+02, -3.42976711e+02,
#         -3.39034227e+02, -3.35091744e+02, -3.31149261e+02, -3.27206777e+02,
#         -3.23264294e+02, -3.19321810e+02, -3.15379327e+02, -3.11436844e+02,
#         -3.07494360e+02, -3.03551877e+02, -2.99609393e+02, -2.95666910e+02,
#         -2.91724427e+02, -2.87781943e+02, -2.83839460e+02, -2.79896976e+02,
#         -2.75954493e+02, -2.72012010e+02, -2.68069526e+02, -2.64127043e+02,
#         -2.60184559e+02, -2.56242076e+02, -2.52299593e+02, -2.48357109e+02,
#         -2.44414626e+02, -2.40472142e+02, -2.36529659e+02, -2.32587176e+02,
#         -2.28644692e+02, -2.24702209e+02, -2.20759725e+02, -2.16817242e+02,
#         -2.12874759e+02, -2.08932275e+02, -2.04989792e+02, -2.01047308e+02,
#         -1.97104825e+02, -1.93162342e+02, -1.89219858e+02, -1.85277375e+02,
#         -1.81334891e+02, -1.77392408e+02, -1.73449925e+02, -1.69507441e+02,
#         -1.65564958e+02, -1.61622474e+02, -1.57679991e+02, -1.53737508e+02,
#         -1.49795024e+02, -1.45852541e+02, -1.41910057e+02, -1.37967574e+02,
#         -1.34025091e+02, -1.30082607e+02, -1.26140124e+02, -1.22197640e+02,
#         -1.18255157e+02, -1.14312674e+02, -1.10370190e+02, -1.06427707e+02,
#         -1.02485223e+02, -9.85427400e+01, -9.46002566e+01, -9.06577732e+01,
#         -8.67152898e+01, -8.27728064e+01, -7.88303230e+01, -7.48878396e+01,
#         -7.09453562e+01, -6.70028728e+01, -6.30603894e+01, -5.91179060e+01,
#         -5.51754226e+01, -5.12329392e+01, -4.72904558e+01, -4.33479724e+01,
#         -3.94054890e+01, -3.54630056e+01, -3.15205222e+01, -2.75780388e+01,
#         -2.36355554e+01, -1.96930720e+01, -1.57505886e+01, -1.18081052e+01,
#         -7.86562185e+00, -3.92313845e+00,  1.93449511e-02,  3.96182835e+00,
#          7.90431175e+00,  1.18467952e+01,  1.57892786e+01,  1.97317619e+01,
#          2.36742453e+01,  2.76167287e+01,  3.15592121e+01,  3.55016955e+01,
#          3.94441789e+01,  4.33866623e+01,  4.73291457e+01,  5.12716291e+01,
#          5.52141125e+01,  5.91565959e+01,  6.30990793e+01,  6.70415627e+01,
#          7.09840461e+01,  7.49265295e+01,  7.88690129e+01,  8.28114963e+01,
#          8.67539797e+01,  9.06964631e+01,  9.46389465e+01,  9.85814299e+01,
#          1.02523913e+02,  1.06466397e+02,  1.10408880e+02,  1.14351364e+02,
#          1.18293847e+02,  1.22236330e+02,  1.26178814e+02,  1.30121297e+02,
#          1.34063781e+02,  1.38006264e+02,  1.41948747e+02,  1.45891231e+02,
#          1.49833714e+02,  1.53776198e+02,  1.57718681e+02,  1.61661164e+02,
#          1.65603648e+02,  1.69546131e+02,  1.73488615e+02,  1.77431098e+02,
#          1.81373581e+02,  1.85316065e+02,  1.89258548e+02,  1.93201032e+02,
#          1.97143515e+02,  2.01085998e+02,  2.05028482e+02,  2.08970965e+02,
#          2.12913449e+02,  2.16855932e+02,  2.20798415e+02,  2.24740899e+02,
#          2.28683382e+02,  2.32625866e+02,  2.36568349e+02,  2.40510832e+02,
#          2.44453316e+02,  2.48395799e+02,  2.52338283e+02,  2.56280766e+02,
#          2.60223249e+02,  2.64165733e+02,  2.68108216e+02,  2.72050700e+02,
#          2.75993183e+02,  2.79935666e+02,  2.83878150e+02,  2.87820633e+02,
#          2.91763117e+02,  2.95705600e+02,  2.99648083e+02,  3.03590567e+02,
#          3.07533050e+02,  3.11475534e+02,  3.15418017e+02,  3.19360500e+02,
#          3.23302984e+02,  3.27245467e+02,  3.31187951e+02,  3.35130434e+02,
#          3.39072917e+02,  3.43015401e+02,  3.46957884e+02,  3.50900368e+02,
#          3.54842851e+02]),
#  <BarContainer object of 180 artists>)

# %%
data
# Out:
#        trial_index  trial_time  response_arrow_start_angle  motion_direction  \
# 0                1    0.000000                       152.0               225
# 1                2    3.685896                       115.0               235
# 2                3    7.748229                       224.0               255
# 3                4   11.060392                        78.0               285
# 4                5   15.223091                       330.0               285
# ...            ...         ...                         ...               ...
# 51353          198  571.895796                        47.0               205
# 51354          199  574.708207                       238.0               265
# 51355          200  577.408906                       300.0               245
# 51356          201  579.720922                        10.0               185
# 51357          202  582.602137                        33.0               185
#
#        motion_coherence  estimate_x  estimate_y  reaction_time  \
# 0                  0.12   -1.613769   -1.909385       2.158201
# 1                  0.12   -2.029838   -1.459369       2.549857
# 2                  0.12   -1.934867   -1.583126       1.799239
# 3                  0.06   -0.957937   -2.309189       2.647172
# 4                  0.06    0.798268   -2.369128       1.980517
# ...                 ...         ...         ...            ...
# 51353              0.06   -0.895369   -2.334162       1.298565
# 51354              0.12   -1.915175   -1.606893       1.175129
# 51355              0.06   -0.076489   -2.498830       0.793728
# 51356              0.12    0.177676   -2.493678       1.363531
# 51357              0.06   -1.507874   -1.994070       1.553555
#
#        raw_response_time  prior_std  ...          experiment_name  \
# 0               3.461231         40  ...  data01_direction4priors
# 1               7.525204         40  ...  data01_direction4priors
# 2              10.837203         40  ...  data01_direction4priors
# 3              14.997142         40  ...  data01_direction4priors
# 4              18.493222         40  ...  data01_direction4priors
# ...                  ...        ...  ...                      ...
# 51353         574.493754         40  ...  data01_direction4priors
# 51354         577.181812         40  ...  data01_direction4priors
# 51355         579.492137         40  ...  data01_direction4priors
# 51356         582.373810         40  ...  data01_direction4priors
# 51357         585.445742         40  ...  data01_direction4priors
#
#        experiment_id session_id  run_id  estimate_degree  estimate_error  \
# 0                 12          6      26       229.796264       -4.796264
# 1                 12          6      26       215.714576       19.285424
# 2                 12          6      26       219.290342       35.709658
# 3                 12          6      26       247.469512       37.530488
# 4                 12          6      26       288.621043       -3.621043
# ...              ...        ...     ...              ...             ...
# 51353             12          6      30       249.013514      -44.013514
# 51354             12          6      30       219.997721       45.002279
# 51355             12          6      30       268.246734      -23.246734
# 51356             12          6      30       274.075461      -89.075461
# 51357             12          6      30       232.904188      -47.904188
#
#        sensory_bias  prior_bias  distance  binarized_estimate_degree
# 0          4.796264    4.796264         0                          0
# 1        -19.285424   -9.285424        10                          1
# 2        -35.709658   -5.709658        30                          1
# 3        -37.530488   22.469512        60                          1
# 4          3.621043   63.621043        60                          0
# ...             ...         ...       ...                        ...
# 51353     44.013514   24.013514        20                          1
# 51354    -45.002279   -5.002279        40                          1
# 51355     23.246734   43.246734        20                          0
# 51356     89.075461   49.075461        40                          1
# 51357     47.904188    7.904188        40                          1
#
# [51358 rows x 22 columns]

# %% [markdown]
# ### Basic data exploration

# %% [markdown]
# Look at the number of sessions and prior runs performed by the subject with subject_id = 1, as well as the prior runs and motion coherences he was exposed to.
# Note that one of three coherences was randomly chosen for each trial within a prior run, which typically lasted 200 trials.

# %%
# @title Experiment design for an example subject

# get subject 1's dataset
sub01_data = data[(data["subject_id"]==1) & data["session_id"]==1][["subject_id", "trial_index", "session_id", "run_id", "prior_std", "motion_coherence", "motion_direction", "estimate_x", "estimate_y"]]

# count the number of trials by run and session
sub01_data.groupby(["subject_id", "session_id", "run_id", "prior_std", "motion_coherence"])[["trial_index"]].count()
# Out:
#                                                          trial_index
# subject_id session_id run_id prior_std motion_coherence
# 1          7          31     20        0.06                      101
#                                        0.12                       75
#                                        0.24                       28
#                       32     80        0.06                      109
#                                        0.12                       75
#                                        0.24                       42
#                       33     80        0.06                      109
#                                        0.12                       75
#                                        0.24                       42
#                       34     40        0.06                       99
#                                        0.12                       74
#                                        0.24                       29
#                       35     10        0.06                      107
#                                        0.12                       74
#                                        0.24                       40

# %%
# @title Temporal order of prior runs by subject for the first session
subject_id_set = data["subject_id"].unique()
n_subjects = len(subject_id_set)
prior_runs_all = []
max_nb_runs = 0

# get sequence of prior runs for each subject
for subject_id in subject_id_set:

  # get subject's dataset
  sub01_data = data[(data["subject_id"]==subject_id) & data["session_id"]==1][["subject_id", "trial_index", "session_id", "run_id", "prior_std", "motion_coherence"]]

  # plot the ordering of prior runs
  gp = sub01_data.groupby(["subject_id", "session_id", "run_id", "prior_std"])[["trial_index"]].count()
  prior_runs = gp.reset_index()["prior_std"].values
  prior_runs_all.append(list(prior_runs))
  max_nb_runs = max(max_nb_runs, len(prior_runs))

# create a matrix that contains the sequence of all subjects' prior runs
run_order_matrix = np.zeros((n_subjects, max_nb_runs))*np.nan
for sub_ix, _ in enumerate(subject_id_set):
  run_order_matrix[sub_ix, 0: len(prior_runs_all[sub_ix])] = prior_runs_all[sub_ix]

# init figure
fig, ax = plt.subplots(1,1)

# create custom colormap
cmp = ListedColormap([[0,.7,.5], [1,.5,0], [1,0,0], [0.7,0,0]])

# set colormap bounds
bounds = [5, 15, 25, 45, 90]
norm = colors.BoundaryNorm(bounds, cmp.N)

# plot sequence of prior runs
plt.imshow(run_order_matrix, cmap=cmp, norm=norm)

# setup x legend
ax.set_xticks(np.arange(1, run_order_matrix.shape[1],1))
ax.set_xticklabels(np.arange(1, run_order_matrix.shape[1],1))
ax.set_xlabel("prior run (order)")

# setup y legend
ax.set_yticks(np.arange(0, run_order_matrix.shape[0],1))
ax.set_yticklabels(subject_id_set)
ax.set_ylabel("subject (id)")

# setup colobar
cbar = plt.colorbar()
cbar.ax.get_yaxis().set_ticks([10,20,40,80])
cbar.ax.get_yaxis().labelpad = 15;
cbar.ax.set_ylabel('prior std (deg)', rotation=270);

# %%
# @title Basic plots of subject estimate average by task conditions

# circular statistics utils
# -------------------
def get_cartesian_to_deg(
    x: np.ndarray, y: np.ndarray, signed: bool
) -> np.ndarray:
    """convert cartesian coordinates to
    angles in degree
    Args:
        x (np.ndarray): x coordinate
        y (np.ndarray): y coordinate
        signed (boolean): True (signed) or False (unsigned)
    Usage:
        .. code-block:: python
            import numpy as np
            from bsfit.nodes.cirpy.utils import get_cartesian_to_deg
            x = np.array([1, 0, -1, 0])
            y = np.array([0, 1, 0, -1])
            degree = get_cartesian_to_deg(x,y,False)
            # Out: array([  0.,  90., 180., 270.])
    Returns:
        np.ndarray: angles in degree
    """
    # convert to radian (ignoring divide by 0 warning)
    with np.errstate(divide="ignore"):
        degree = np.arctan(y / x)

    # convert to degree and adjust based
    # on quadrant
    for ix in range(len(x)):
        if (x[ix] >= 0) and (y[ix] >= 0):
            degree[ix] = degree[ix] * 180 / np.pi
        elif (x[ix] == 0) and (y[ix] == 0):
            degree[ix] = 0
        elif x[ix] < 0:
            degree[ix] = degree[ix] * 180 / np.pi + 180
        elif (x[ix] >= 0) and (y[ix] < 0):
            degree[ix] = degree[ix] * 180 / np.pi + 360

    # if needed, convert signed to unsigned
    if not signed:
        degree[degree < 0] = degree[degree < 0] + 360
    return degree

def get_deg_to_rad(deg: np.array, signed: bool):
    """convert angles in degree to radian
    Args:
        deg (np.array): angles in degree
        signed (bool): True (signed) or False (unsigned)
    Usage:
        .. code-block:: python
            import numpy as np
            from bsfit.nodes.cirpy.utils import get_deg_to_rad
            radians = get_deg_to_rad(np.array([0, 90, 180, 270], True)
            Out: array([ 0., 1.57079633, 3.14159265, -1.57079633])
    Returns:
        np.ndarray: angles in radian
    """
    # get unsigned radians (1:2*pi)
    rad = (deg / 360) * 2 * pi

    # get signed radians(-pi:pi)
    if signed:
        rad[deg > 180] = (deg[deg > 180] - 360) * (
            2 * pi / 360
        )
    return rad

def get_polar_to_cartesian(
    angle: np.ndarray, radius: float, type: str
) -> dict:
    """convert angle in degree or radian to cartesian coordinates
    Args:
        angle (np.ndarray): angles in degree or radian
        radius (float): radius
        type (str): "polar" or "radian"
    Usage:
        .. code-block:: python
            import numpy as np
            from bsfit.nodes.cirpy.utils import get_polar_to_cartesian
            degree = np.array([0, 90, 180, 270])
            cartesian = get_polar_to_cartesian(degree, 1, "polar")
            cartesian.keys()

            # Out: dict_keys(['deg', 'rad', 'cart'])

            cartesian["cart"]

            # Out: array([[ 1.,  0.],
            #            [ 0.,  1.],
            #            [-1.,  0.],
            #            [-0., -1.]])
    Returns:
        dict: _description_
    """
    # convert to radian if needed
    theta = dict()
    if type == "polar":
        theta["deg"] = angle
        theta["rad"] = angle * np.pi / 180
    elif type == "radian":
        theta["deg"] = get_deg_to_rad(angle, False)
        theta["rad"] = angle

    # convert to cartesian coordinates
    x = radius * np.cos(theta["rad"])
    y = radius * np.sin(theta["rad"])

    # round to 10e-4
    x = np.round(x, 4)
    y = np.round(y, 4)

    # reshape as (N angles x 2 coord)
    theta["cart"] = np.vstack([x, y]).T
    return theta

def get_circ_weighted_mean_std(
    angle: np.ndarray, proba: np.ndarray, type: str
) -> dict:
    """calculate circular data statistics
    Args:
        angle (np.ndarray): angles in degree or cartesian coordinates
        proba (np.ndarray): each angle's probability of occurrence
        type (str): "polar" or "cartesian"
    Usage:
        .. code-block:: python
            import numpy as np
            from bsfit.nodes.cirpy.utils import get_circ_weighted_mean_std
            degree = np.array([358, 0, 2, 88, 90, 92])
            proba = np.array([1, 1, 1, 1, 1, 1])/6
            output = get_circ_weighted_mean_std(degree, proba, "polar")
            output.keys()
            # Out: dict_keys(['coord_all', 'deg_all', 'coord_mean', 'deg_mean',
            #               'deg_all_for_std', 'deg_mean_for_std', 'deg_var',
            #               'deg_std', 'deg_sem'])
            output["deg_mean"]
            # Out: array([45.])
            output["deg_std"]
            # array([45.02961988])
    Returns:
        (dict): angle summary statistics (mean, std, var, sem)

    Raises:
        ValueError: type is not "polar" or "cartesian"
    """

    angle = angle.copy()

    # if polar, convert to cartesian
    if type == "polar":
        radius = 1
        coord = get_polar_to_cartesian(
            angle, radius=radius, type="polar"
        )
    elif type == "cartesian":
        coord = angle
    else:
        raise ValueError(
            """ "type" can either be "polar" or "cartesian" value """
        )

    # store angles
    data = dict()
    data["coord_all"] = coord["cart"]
    data["deg_all"] = coord["deg"]

    # calculate mean
    # ..............
    proba_for_mean = np.tile(proba[:, None], 2)
    data["coord_mean"] = np.sum(
        proba_for_mean * data["coord_all"], 0
    )
    data["coord_mean"] = data["coord_mean"][:, None]
    data["deg_mean"] = get_cartesian_to_deg(
        data["coord_mean"][0],
        data["coord_mean"][1],
        signed=False,
    )

    # calculate std
    # ..............
    n_data = len(data["deg_all"])
    data["deg_all_for_std"] = data["deg_all"]
    data["deg_mean_for_std"] = np.tile(
        data["deg_mean"], n_data
    )

    # apply corrections
    # when 0 <= mean <= 180
    if data["deg_mean"] + 180 <= 360:
        for ix in range(n_data):
            if (
                data["deg_all"][ix]
                >= data["deg_mean"] + 180
            ):
                data["deg_all_for_std"][ix] = (
                    data["deg_all"][ix] - 360
                )
    else:
        # when 180 <= mean <= 360
        for ix in range(n_data):
            if (
                data["deg_all"][ix]
                <= data["deg_mean"] - 180
            ):
                data["deg_mean_for_std"][ix] = (
                    data["deg_mean"] - 360
                )

    # calculate variance, standard deviation and
    # standard error to the mean
    data["deg_var"] = np.array(
        [
            sum(
                proba
                * (
                    data["deg_all_for_std"]
                    - data["deg_mean_for_std"]
                )
                ** 2
            )
        ]
    )
    data["deg_std"] = np.sqrt(data["deg_var"])
    data["deg_sem"] = data["deg_std"] / np.sqrt(n_data)
    return data

def get_signed_angle(
    origin: np.ndarray, destination: np.ndarray, type: str
):
    """get the signed angle difference between origin and destination angles
    Args:
        origin (np.ndarray): origin angle
        destination (np.ndarray): destination angle
        type (str): angle type ("polar", "radian", "cartesian")
    Usage:
        .. code-block:: python
            angle = get_signed_angle(90, 45, 'polar')

            # Out: array([45.])

            angle = get_signed_angle(90, 45, 'radian')
            # Out: array([58.3103779])
            origin = np.array([[0, 1]])
            destination = np.array([[1, 0]])
            angle = get_signed_angle(origin, destination, "cartesian")

            # Out: array([90.])
    Returns:
        (np.ndarray): signed angle differences
    """

    # convert to cartesian coordinates
    if type == "polar" or type == "radian":
        origin_dict = get_polar_to_cartesian(
            origin, radius=1, type=type
        )
        destination_dict = get_polar_to_cartesian(
            destination, radius=1, type=type
        )
    elif type == "cartesian":
        origin_dict = dict()
        destination_dict = dict()
        origin_dict["cart"] = origin
        destination_dict["cart"] = destination

    # get coordinates
    xV1 = origin_dict["cart"][:, 0]
    yV1 = origin_dict["cart"][:, 1]
    xV2 = destination_dict["cart"][:, 0]
    yV2 = destination_dict["cart"][:, 1]

    # Calculate the angle separating the
    # two vectors in degrees
    angle = -(180 / np.pi) * np.arctan2(
        xV1 * yV2 - yV1 * xV2, xV1 * xV2 + yV1 * yV2
    )
    return angle

def get_combination_set(database: np.ndarray):
    """get the set of row combinations

    Args:
        database (np.ndarray): an N-D array

    Returns:
        (np.ndarray, np.ndarray, np.ndarray): `combs` is the set
        of combinations, `b` are the row indices for each combination
        in database, `c` are the rows indices for each combination in
        combs.
    """
    combs, ia, ic = np.unique(
        database,
        return_index=True,
        return_inverse=True,
        axis=0,
    )
    return (combs, ia, ic)

def get_data_stats(data: pd.Series, output: dict):
    """calculate data statistics

    Args:
        data (pd.Series): stimulus feature estimates
        output (dict): ::

            'PestimateGivenModel': estimate probabilities
            'map': max-a-posteriori percepts
            'conditions': task conditions

    Returns:
        (dict): returns data mean and std to output
    """
    # get conditions
    cond = output["conditions"]

    # initialise statistics
    data_mean = []
    data_std = []

    # get set of conditions
    cond_set, ix, _ = get_combination_set(cond)

    # record stats by condition
    for c_i in range(len(cond_set)):

        # find condition's instances
        loc_1 = cond[:, 0] == cond_set[c_i, 0]
        loc_2 = cond[:, 1] == cond_set[c_i, 1]
        loc_3 = cond[:, 2] == cond_set[c_i, 2]

        # get associated data
        data_c_i = data.values[loc_1 & loc_2 & loc_3]

        # set each instance with equal probability
        trial_proba = np.tile(
            1 / len(data_c_i), len(data_c_i)
        )

        # get statistics
        stats = get_circ_weighted_mean_std(
            data_c_i, trial_proba, type="polar",
        )

        # record statistics
        data_mean.append(stats["deg_mean"])
        data_std.append(stats["deg_std"])

    # record statistics
    output["data_mean"] = np.array(data_mean)
    output["data_std"] = np.array(data_std)

    # record their condition
    output["conditions"] = cond_set
    return output


# Visualization utils
# -------------------
def plot_mean(
    data_mean: np.ndarray,
    data_std: np.ndarray,
    condition: np.ndarray,
    prior_mode: float,
    centering: bool,
):
    """plot data and prediction mean and std
    for three conditions (x-axis, colors and panels)
    Args:
        data_mean (np.ndarray): data mean by condition
        data_std (np.ndarray): data std by condition
        prediction_mean (np.ndarray): prediction mean by condition
        prediction_std (np.ndarray): prediction std by condition
        condition (np.ndarray): associated conditions
        prior_mode (float): the mode of the prior
        centering (bool): center x-axis or not
    Returns:
        _type_: _description_
    """
    # get condition levels
    levels_1 = np.flip(np.unique(condition[:, 0]))
    levels_2 = np.flip(np.unique(condition[:, 1])) # sort in decreasing order
    levels_3 = np.unique(condition[:, 2])

    # set x_tick
    x_tick_centered = get_signed_angle(
        levels_1, prior_mode, "polar"
    )
    x_tick_centered[x_tick_centered == -180] = 180
    i_sort = np.argsort(x_tick_centered)
    x_tick_centered = x_tick_centered[i_sort]
    y_tick_centered = x_tick_centered

    # set colors
    levels_2_color = [
        [0.5, 0, 0],
        [1, 0.2, 0],
        [1, 0.6, 0],
        [0.75, 0.75, 0],
    ]

    plt.figure(figsize=(10,3))

    # loop over conditions and plot data
    # and prediction stats
    for level2_ix in range(len(levels_2)):

        # set condition 2 in column panels
        plt.subplot(1, len(levels_2), level2_ix + 1)

        # set condition 3 within panels
        for level1_ix in range(len(levels_1)):

            # find condition's instances
            loc_lev1 = (
                condition[:, 0] == levels_1[level1_ix]
            )
            loc_lev2 = (
                condition[:, 1] == levels_2[level2_ix]
            )
            loc_condition = loc_lev2 & loc_lev1

            # center to prior mode
            x_centered = condition[:, 2][loc_condition]
            if centering:
                x_centered = np.round(
                    get_signed_angle(
                        x_centered, prior_mode, "polar",
                    )
                )

            x_centered[x_centered == -180] = 180

            # make 2-D array
            x_centered = x_centered[:, None]

            # sort data stats
            y_data_centered = data_mean[loc_condition]
            y_data_std_centered = data_std[loc_condition]

            # sort all
            i_sort = np.argsort(x_centered.squeeze())
            x_centered = x_centered[i_sort]
            y_data_centered = y_data_centered[i_sort]
            y_data_std_centered = y_data_std_centered[
                i_sort
            ]

            # To plot estimates mean against circular stimulus
            # feature on a linear space, the raw stimulus feature and
            # estimates mean are normalized to vectorial angles from
            # the prior mode and x and y axes are centered at zero
            # (normalized prior mode) via a circular shift. Rotation
            # angles were then labelled according to their raw values
            # on the circle (e.g., 0, is labelled 225). A mean estimate
            # of 33 degree was calculated for 55 degree which is very far
            # from stimulus feature on the linear space but actually close
            # to stimulus feature on the circular space. We got rid of
            # this visual artifact by expressing both 55 and 33 as the
            # counterclockwise distance to prior mode (e.g., for a prior
            # mode 225 55 becomes 190 instead of 170 and 33 becomes 168).
            # Note that the maximum vectorial angle is >180.
            if (level2_ix == 3) & (not 180 in x_centered):

                # move point at -170? distance to prior at 190? (positive
                # side) and convert values at x=-170? to positive distance
                # relative to prior to improve visualization
                posNeg170 = x_centered == -170
                x_centered[posNeg170] = (
                    prior_mode - 170 + 360 - prior_mode
                )
                x_centered[x_centered == 180] = -180
                y_data_centered[posNeg170] = (
                    prior_mode
                    - abs(y_data_centered[posNeg170])
                    + 360
                    - prior_mode
                )

                # sort x-axis
                i_sort = np.argsort(x_centered)
                x_centered = x_centered[i_sort]

                # sort y-axis
                y_data_centered = y_data_centered[i_sort]

                # set ticks
                x_tick_centered = x_centered

            # plot data stats
            plt.errorbar(
                x_centered.squeeze(),
                y_data_centered.squeeze(),
                yerr=y_data_std_centered.squeeze(),
                marker="o",
                markersize=7,
                markeredgecolor="w",
                linestyle="None",
                linewidth=1,
                color=levels_2_color[level1_ix],
                ecolor=levels_2_color[level1_ix],
            )
            plt.ylim([-0, 360])
            plt.hlines(prior_mode, -180, 180, linestyle=':')
            plt.xticks([-160, -80, 0, 80, 160], [-160, -80, 0, 80, 160])
            plt.yticks([67, 147, 227, 307, 387], [-160, -80, 0, 80, 160])
            plt.xlabel("Motion direction distance" "\n" "relative to the prior mean" "\n" "(deg)")
            if level2_ix == 0:
              plt.ylabel("Mean estimates distance" "\n" "relative to the prior mean" "\n" "(deg)")
        plt.title(f"{int(levels_2[level2_ix]*100)}% coherence", fontsize=12)
    plt.show()
    return None

# %% [markdown]
# Priors are color coded (green: 10 deg, orange: 20 deg, red: 40 deg, dark red: 80 deg)

# %%
# convert subject estimate cartesian coordinates to degrees
estimates_deg = get_cartesian_to_deg(data["estimate_x"].values, data["estimate_y"].values, False)
estimates_deg = np.round(estimates_deg)

# calculate estimate circular summary statistics by experimental condition
stats = dict()
stats["conditions"] = data[["prior_std", "motion_coherence", "motion_direction"]].values
stats = get_data_stats(pd.Series(estimates_deg), stats)

# plot estimate average
plot_mean(
  stats["data_mean"],
  stats["data_std"],
  stats["conditions"],
  prior_mode=225,
  centering=True
)

# %%
# @title Plots of estimate average by task condition and subject

subject_id_set = data["subject_id"].unique()

for sub_id in subject_id_set:

  dataset = data[data["subject_id"]==sub_id]

  # convert subject estimate cartesian coordinates to degrees
  estimates_deg = get_cartesian_to_deg(dataset["estimate_x"].values, dataset["estimate_y"].values, False)
  estimates_deg = np.round(estimates_deg)

  # calculate estimate circular summary statistics by experimental condition
  stats = dict()
  stats["conditions"] = dataset[["prior_std", "motion_coherence", "motion_direction"]].values
  stats = get_data_stats(pd.Series(estimates_deg), stats)

  # plot estimate average
  plot_mean(
    stats["data_mean"],
    stats["data_std"],
    stats["conditions"],
    prior_mode=225,
    centering=True
  )

# %%
# @title Plot session time course of subject 1's individual trial estimates (24% coh, 80 deg prior)

# set parameters
SUBJECT_ID = 1
COHERENCE = 0.24
PRIOR_STD = 80

# set session ids
session_ids = [1,3,5,7]

fig, axes = plt.subplots(1,len(session_ids), figsize=(10,3))

for ix, session_id in enumerate(session_ids):

  # query the data we need
  tmp = data[(data["subject_id"]==SUBJECT_ID) & (data["session_id"]==session_id) & (data["motion_coherence"]==COHERENCE) & (data["prior_std"]==PRIOR_STD)]

  # get data
  motion_direction = tmp["motion_direction"].values
  estimates_deg = np.round(get_cartesian_to_deg(tmp["estimate_x"].values, tmp["estimate_y"].values, False))

  # plot subject 01's estimates against true motion direction
  axes[ix].plot([ix, 360], [0, 360], "r--");
  axes[ix].plot(motion_direction, estimates_deg, color=[0.5, 0, 0], marker="o", linestyle="None", markersize=6, markeredgecolor="w");
  axes[ix].set_xlabel("Motion direction (deg)");
  if ix==0:
    axes[ix].set_ylabel("Choice estimate (deg)");
  axes[ix].set_xlim([0, 360]);
  axes[ix].set_ylim([0, 360]);
  axes[ix].axis("square");
  axes[ix].set_title(f"Session {session_id}", fontsize=12)
plt.tight_layout()

# %%
# @title Do estimate errors stay stable over time? (24% coh)
prior_stds = data["prior_std"].unique()
prior_colors = [[0.75, 0.75, 0],
                [1, 0.6, 0],
                [1, 0.2, 0],
                [0.5, 0, 0]]

# setup plots
fig, axes = plt.subplots(len(prior_stds), len(session_ids), figsize=(15,8))

# plot motion directions and choice estimates time course
for p_i, prior_std_i in enumerate(prior_stds):
  for s_i, session_id in enumerate(session_ids):

    # query the data we need
    tmp = data[(data["subject_id"]==SUBJECT_ID) & (data["session_id"]==session_id) & (data["motion_coherence"]==COHERENCE) & (data["prior_std"]==prior_std_i)]

    # get data
    motion_direction = tmp["motion_direction"].values
    estimates_deg = np.round(get_cartesian_to_deg(tmp["estimate_x"].values, tmp["estimate_y"].values, False))

    # calculate circular error
    error = get_signed_angle(
        motion_direction, estimates_deg, type='polar'
    )

    # plot circular error
    axes[p_i,s_i].bar(x=np.arange(0, len(estimates_deg),1), height=error, color=prior_colors[p_i]);

    # add legend
    if p_i==0:
      axes[p_i,s_i].set_title(f"Session {session_id} (24% coh)");
    if s_i==0:
      axes[p_i,s_i].set_ylabel(f"Error for {prior_std_i} deg"  "\n" "prior (deg)");
    if p_i==len(prior_stds)-1:
      axes[p_i,s_i].set_xlabel("Trials");
